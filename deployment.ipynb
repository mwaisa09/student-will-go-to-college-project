# %% [markdown]
# **Import The Library**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pickle

# %% [markdown]
# **Load The Dataset**

# %%
df = pd.read_csv('student.csv')
df
# Out:
#     type_school school_accreditation  gender         interest residence  \
# 0      Academic                    A    Male  Less Interested     Urban
# 1      Academic                    A    Male  Less Interested     Urban
# 2      Academic                    B  Female  Very Interested     Urban
# 3    Vocational                    B    Male  Very Interested     Rural
# 4      Academic                    A  Female  Very Interested     Urban
# ..          ...                  ...     ...              ...       ...
# 995  Vocational                    A  Female  Very Interested     Rural
# 996    Academic                    B  Female  Less Interested     Rural
# 997  Vocational                    A    Male  Less Interested     Urban
# 998    Academic                    B    Male        Uncertain     Rural
# 999    Academic                    B    Male       Interested     Urban
#
#      parent_age  parent_salary  house_area  average_grades  \
# 0            56        6950000        83.0           84.09
# 1            57        4410000        76.8           86.91
# 2            50        6500000        80.6           87.43
# 3            49        6600000        78.2           82.12
# 4            57        5250000        75.1           86.79
# ..          ...            ...         ...             ...
# 995          49        7420000        63.6           85.99
# 996          51        7480000        84.3           89.72
# 997          49        5550000        75.2           79.56
# 998          53        5840000       105.8           87.18
# 999          50        2940000        69.1           86.13
#
#      parent_was_in_college  will_go_to_college
# 0                    False                True
# 1                    False                True
# 2                    False                True
# 3                     True                True
# 4                    False               False
# ..                     ...                 ...
# 995                   True                True
# 996                   True                True
# 997                  False                True
# 998                   True                True
# 999                   True               False
#
# [1000 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   type_school            1000 non-null   object
#  1   school_accreditation   1000 non-null   object
#  2   gender                 1000 non-null   object
#  3   interest               1000 non-null   object
#  4   residence              1000 non-null   object
#  5   parent_age             1000 non-null   int64
#  6   parent_salary          1000 non-null   int64
#  7   house_area             1000 non-null   float64
#  8   average_grades         1000 non-null   float64
#  9   parent_was_in_college  1000 non-null   bool
#  10  will_go_to_college     1000 non-null   bool
# dtypes: bool(2), float64(2), int64(2), object(5)
# memory usage: 72.4+ KB

# %%
df.count()
# Out:
# type_school              1000
# school_accreditation     1000
# gender                   1000
# interest                 1000
# residence                1000
# parent_age               1000
# parent_salary            1000
# house_area               1000
# average_grades           1000
# parent_was_in_college    1000
# will_go_to_college       1000
# dtype: int64

# %% [markdown]
# **Preprocessing The Data**

# %%
missing = pd.DataFrame({
    'Data Kosong': df.isnull().sum(),
    'Data Duplikat': df.duplicated().sum(),
    'Data NaNN': df.isna().sum(),
    'Type Data': df.dtypes})
missing
# Out:
#                        Data Kosong  Data Duplikat  Data NaNN Type Data
# type_school                      0              0          0    object
# school_accreditation             0              0          0    object
# gender                           0              0          0    object
# interest                         0              0          0    object
# residence                        0              0          0    object
# parent_age                       0              0          0     int64
# parent_salary                    0              0          0     int64
# house_area                       0              0          0   float64
# average_grades                   0              0          0   float64
# parent_was_in_college            0              0          0      bool
# will_go_to_college               0              0          0      bool

# %%
# Encoding The Categorical Value
df['type_school'] = LabelEncoder().fit_transform(df['type_school'])
df['school_accreditation'] = LabelEncoder().fit_transform(df['school_accreditation'])
df['gender'] = LabelEncoder().fit_transform(df['gender'])
df['interest'] = LabelEncoder().fit_transform(df['interest'])
df['residence'] = LabelEncoder().fit_transform(df['residence'])
df['parent_was_in_college'] = LabelEncoder().fit_transform(df['parent_was_in_college'])
df['will_go_to_college'] = LabelEncoder().fit_transform(df['will_go_to_college'])
df.head(10)
# Out:
#    type_school  school_accreditation  gender  interest  residence  parent_age  \
# 0            0                     0       1         1          1          56
# 1            0                     0       1         1          1          57
# 2            0                     1       0         4          1          50
# 3            1                     1       1         4          0          49
# 4            0                     0       0         4          1          57
# 5            1                     1       0         1          0          48
# 6            0                     0       1         4          0          52
# 7            0                     1       1         4          0          53
# 8            0                     1       0         3          0          52
# 9            0                     1       0         4          0          47
#
#    parent_salary  house_area  average_grades  parent_was_in_college  \
# 0        6950000        83.0           84.09                      0
# 1        4410000        76.8           86.91                      0
# 2        6500000        80.6           87.43                      0
# 3        6600000        78.2           82.12                      1
# 4        5250000        75.1           86.79                      0
# 5        3770000        65.3           86.79                      1
# 6        6680000        85.5           90.39                      1
# 7        5890000        83.3           84.65                      1
# 8        6730000        80.3           88.50                      1
# 9        3880000        68.0           85.43                      1
#
#    will_go_to_college
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   0
# 5                   0
# 6                   1
# 7                   0
# 8                   1
# 9                   0

# %%
df.describe()
# Out:
#        type_school  school_accreditation       gender     interest  \
# count  1000.000000           1000.000000  1000.000000  1000.000000
# mean      0.391000              0.519000     0.515000     2.480000
# std       0.488219              0.499889     0.500025     1.399127
# min       0.000000              0.000000     0.000000     0.000000
# 25%       0.000000              0.000000     0.000000     1.000000
# 50%       0.000000              1.000000     1.000000     3.000000
# 75%       1.000000              1.000000     1.000000     4.000000
# max       1.000000              1.000000     1.000000     4.000000
#
#          residence   parent_age  parent_salary   house_area  average_grades  \
# count  1000.000000  1000.000000   1.000000e+03  1000.000000     1000.000000
# mean      0.539000    52.208000   5.381570e+06    74.515300       86.097200
# std       0.498726     3.500427   1.397546e+06    15.293346        3.378738
# min       0.000000    40.000000   1.000000e+06    20.000000       75.000000
# 25%       0.000000    50.000000   4.360000e+06    64.600000       83.737500
# 50%       1.000000    52.000000   5.440000e+06    75.500000       85.575000
# 75%       1.000000    54.000000   6.382500e+06    84.825000       88.262500
# max       1.000000    65.000000   1.000000e+07   120.000000       98.000000
#
#        parent_was_in_college  will_go_to_college
# count             1000.00000          1000.00000
# mean                 0.52000             0.50000
# std                  0.49985             0.50025
# min                  0.00000             0.00000
# 25%                  0.00000             0.00000
# 50%                  1.00000             0.50000
# 75%                  1.00000             1.00000
# max                  1.00000             1.00000

# %%
df.corr()
# Out:
#                        type_school  school_accreditation    gender  interest  \
# type_school               1.000000             -0.020216  0.027206  0.062017
# school_accreditation     -0.020216              1.000000 -0.049198  0.004122
# gender                    0.027206             -0.049198  1.000000 -0.013164
# interest                  0.062017              0.004122 -0.013164  1.000000
# residence                -0.245634             -0.263958  0.009694 -0.243472
# parent_age               -0.108553             -0.165869  0.090292 -0.167770
# parent_salary             0.134980             -0.020740 -0.017202  0.170154
# house_area               -0.039654              0.115532 -0.008192  0.285150
# average_grades           -0.074534              0.159689  0.027878  0.150690
# parent_was_in_college     0.146354              0.525279 -0.059274  0.140842
# will_go_to_college       -0.034838             -0.030022 -0.034015  0.247421
#
#                        residence  parent_age  parent_salary  house_area  \
# type_school            -0.245634   -0.108553       0.134980   -0.039654
# school_accreditation   -0.263958   -0.165869      -0.020740    0.115532
# gender                  0.009694    0.090292      -0.017202   -0.008192
# interest               -0.243472   -0.167770       0.170154    0.285150
# residence               1.000000    0.527456      -0.297498   -0.241503
# parent_age              0.527456    1.000000      -0.286418    0.107060
# parent_salary          -0.297498   -0.286418       1.000000    0.138357
# house_area             -0.241503    0.107060       0.138357    1.000000
# average_grades         -0.218412   -0.006077       0.306712    0.409565
# parent_was_in_college  -0.619502   -0.438322       0.106487    0.145186
# will_go_to_college      0.006018    0.042873       0.475693    0.467267
#
#                        average_grades  parent_was_in_college  \
# type_school                 -0.074534               0.146354
# school_accreditation         0.159689               0.525279
# gender                       0.027878              -0.059274
# interest                     0.150690               0.140842
# residence                   -0.218412              -0.619502
# parent_age                  -0.006077              -0.438322
# parent_salary                0.306712               0.106487
# house_area                   0.409565               0.145186
# average_grades               1.000000               0.236713
# parent_was_in_college        0.236713               1.000000
# will_go_to_college           0.505133               0.048038
#
#                        will_go_to_college
# type_school                     -0.034838
# school_accreditation            -0.030022
# gender                          -0.034015
# interest                         0.247421
# residence                        0.006018
# parent_age                       0.042873
# parent_salary                    0.475693
# house_area                       0.467267
# average_grades                   0.505133
# parent_was_in_college            0.048038
# will_go_to_college               1.000000

# %%
df['type_school'] = df['type_school'].astype('category')
df['school_accreditation'] = df['school_accreditation'].astype('category')
df['gender'] = df['gender'].astype('category')
df['interest'] = df['interest'].astype('category')
df['residence'] = df['residence'].astype('category')
df['parent_was_in_college'] = df['parent_was_in_college'].astype('category')
df['will_go_to_college'] = df['will_go_to_college'].astype('category')

# %%
# Feature Selection
X = df.drop(columns='will_go_to_college')
y = df.will_go_to_college

# %% [markdown]
# **Standardized The Data**

# %%
columns = ['parent_salary','house_area','parent_age','average_grades']
scaler = MinMaxScaler()
X[columns] = scaler.fit_transform(X[columns])

# %% [markdown]
# **Splitting Training and Testing Data**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((900, 10), (100, 10), (900,), (100,))

# %% [markdown]
# **Train the Model**

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# **Evaluate The Model**

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)

# %%
print('Akurasi data training adalah :', training_data_accuracy)
# Out:
# Akurasi data training adalah : 1.0

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)

# %%
print('Akurasi data testing :', test_data_accuracy)
# Out:
# Akurasi data testing : 0.85

# %%
print(classification_report(X_test_prediction, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84        47
#            1       0.87      0.85      0.86        53
#
#     accuracy                           0.85       100
#    macro avg       0.85      0.85      0.85       100
# weighted avg       0.85      0.85      0.85       100

# %%
cm = confusion_matrix(X_test_prediction, y_test)
cm
# Out:
# array([[40,  7],
#        [ 8, 45]], dtype=int64)

# %% [markdown]
# **Build the Predictive Model**

# %% [markdown]
# **Save The Model**

# %%
pickle.dump(model, open("klasifikasi.pkl","wb"))

# %%
pickle.dump(scaler, open("scaler.pkl","wb"))
